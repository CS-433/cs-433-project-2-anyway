# %%
import torch
import numpy as np
import pandas as pd
from torch.autograd import Variable as V
import torchvision.models as models
from torchvision import transforms as trn
from torch.nn import functional as F
import os
from PIL import Image
from imutils import paths
from places365.detector_best import build_detect

# %%
import os
os.chdir(r"./places365")

# %%
# th architecture to use
arch = 'resnet18'

# load the pre-trained weights
model_file = '%s_places365.pth.tar' % arch
if not os.access(model_file, os.W_OK):
    weight_url = 'http://places2.csail.mit.edu/models_places365/' + model_file
    os.system('wget ' + weight_url)

model = models.__dict__[arch](num_classes=365)
checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
model.load_state_dict(state_dict)
model.eval()


# load the image transformer
centre_crop = trn.Compose([
        trn.Resize((256,256)),
        trn.CenterCrop(224),
        trn.ToTensor(),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# load the class label
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = tuple(classes)

# %%
'''New 2020-11-28'''
def f_detect(img_name): # new for direct view
    # th architecture to use
    arch = 'resnet18'

    # load the pre-trained weights
    model_file = '%s_places365.pth.tar' % arch
    if not os.access(model_file, os.W_OK):
        weight_url = 'http://places2.csail.mit.edu/models_places365/' + model_file
        os.system('wget ' + weight_url)

    model = models.__dict__[arch](num_classes=365)
    checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
    state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
    model.load_state_dict(state_dict)
    model.eval()


    # load the image transformer
    centre_crop = trn.Compose([
            trn.Resize((256,256)),
            trn.CenterCrop(224),
            trn.ToTensor(),
            trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    # load the class label
    file_name = 'categories_places365.txt'
    if not os.access(file_name, os.W_OK):
        synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
        os.system('wget ' + synset_url)
    classes = list()
    with open(file_name) as class_file:
        for line in class_file:
            classes.append(line.strip().split(' ')[0][3:])
    classes = tuple(classes)
    
    # Load the building list
    df = pd.read_csv("building_class_list.csv")
    buildings = list(df['class'])

    # Open the img
    img = Image.open(img_name)
    input_img = V(centre_crop(img).unsqueeze(0))

    # forward pass
    logit = model.forward(input_img)
    h_x = F.softmax(logit, 1).data.squeeze()
    prob_all, label_all = h_x.sort(0, True)

    # find the best label which is building (from the first two highest prob)
    prob_all = list(prob_all)
    label_all = list(label_all)
    best_prob = prob_all[0]
    best_label = label_all[0]
    count = 0
    while(best_label not in buildings and count<3):
        count += 1
        prob_all.remove(best_prob)
        label_all.remove(best_label)
        if not prob_all:
            break
        else:
            best_prob = prob_all[0]
            best_label = label_all[0]
        
    return best_prob,best_label

# %%
def return_num_img(img_path):
    arr = img_path.split("/")
    name = arr[len(arr)-1]
    arr = name.split("_")
    num = arr[len(arr)-1].split(".")[0]
    
    return num

# %%
# Load the test image
imgPaths = sorted(list(paths.list_images("./test_imgs/")))
path_to_save = "./test_imgs/"
for imgPath in imgPaths:
    num = return_num_img(imgPath)
    name = "gsv_4" + num + ".jpg"
    path_renamed = path_to_save + name
    img = Image.open(imgPath)
    img.save(path_renamed)

# %%
# Load the test image
imgPath = sorted(list(paths.list_images("./test_imgs")))
# Path to save the dataset
path_to_save = "./data/buildings/"
while(imgPath):
    print(imgPath.pop())
# Out:
# ./data/test_imgs\img_8.png
# ./data/test_imgs\img_7.png
# ./data/test_imgs\img_6.png
# ./data/test_imgs\img_5.png
# ./data/test_imgs\img_4.png
# ./data/test_imgs\img_3.png
# ./data/test_imgs\img_20.png
# ./data/test_imgs\img_2.png
# ./data/test_imgs\img_18.png
# ./data/test_imgs\img_17.png
# ./data/test_imgs\img_16.png
# ./data/test_imgs\img_14.png
# ./data/test_imgs\img_13.png
# ./data/test_imgs\img_12.png
# ./data/test_imgs\img_11.png
# ./data/test_imgs\img_10.png
# ./data/test_imgs\img_1.png
# ./data/test_imgs\img_0.png

# %%
# Load the test image
imgPath = sorted(list(paths.list_images("./test_imgs")))
# Path to save the dataset
path_to_save = "./test_imgs/save"

# Load the classes
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = tuple(classes)


# Load the building list
df = pd.read_csv("../building_class_list.csv")
buildings = list(df['class'])

class_save = []
idxes = []
names = []
probility = []
reasons = []
save = []

while(imgPath):
    image = imgPath.pop()
    # Building detection
    try:
        prob,label = f_detect(image)
    except:
        continue

    name = image.replace("./data/test_imgs","")
    names.append(name)
    class_save.append(classes[label])
    idxes.append(label)
    detect = 0

    img = Image.open(image)
    if label in buildings: # Check if one of the top two classes detected is building
        if prob > 0.06: # Filter out the image if the probability is less than 0.1
            print('Save: ', name)
            path_buildings = path_to_save + name
            img.save(path_buildings)
            detect = 1
            reason = "None"
        else: # write to csv - reason - prob less than threshold
            reason = "prob less than threshold"
            prob = 0.0
            print(reason)
    else: # write to csv - reason - no building detected
        prob = 0.0
        reason = "no building detected"
        print(reason)
        
    probility.append(prob)
    reasons.append(reason)
    save.append(detect)

df_class = pd.DataFrame(class_save,columns =['class'])
df_idxes = pd.DataFrame(idxes)
df_names = pd.DataFrame(names)
df_save = pd.DataFrame(save)
df_probility = pd.DataFrame(probility)
df_reasons = pd.DataFrame(reasons)
df_class['names'] = df_names
#df_class['img_index']
df_class['idxes'] = df_idxes
df_class['detected_building'] = df_save
df_class['probility'] = df_probility
df_class['reason_unsaved'] = df_reasons
df_class.to_csv('df_class.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-24bb9ed54771> in <module>
#      17
#      18 # Load the building list
# ---> 19 df = pd.read_csv("building_class_list.csv")
#      20 buildings = list(df['class'])
#      21
#
# c:\users\13434\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\13434\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\users\13434\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# c:\users\13434\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# c:\users\13434\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'building_class_list.csv'

# %%
'''2020-11-28'''
# Load the test image   
imgPath = sorted(list(paths.list_images("./data/Unlabel")))
# Path to save the dataset
path_to_save = "./data/buildings/"

# Load the classes
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = tuple(classes)

# Load the building list
df = pd.read_csv("building_class_list.csv")
buildings = list(df['class'])

class_save = []
idxes = []
names = []
probility = []
reasons = []
save = []

while(imgPath):
    image = imgPath.pop()
    # Building detection
    try:
        prob,label = f_detect(image)
    except:
        continue

    name = image.replace("./data/Unlabel","")
    names.append(name)
    class_save.append(classes[label])
    idxes.append(label)
    detect = 0

    img = Image.open(image)
    if label in buildings: # Check if one of the top two classes detected is building
        if prob > 0.07: # Filter out the image if the probability is less than 0.1
            print('Save: ', name)
            path_buildings = path_to_save + name
            img.save(path_buildings)
            detect = 1
            reason = "None"
        else: # write to csv - reason - prob less than threshold
            prob = 0.0
            reason = "prob less than threshold"
            print(reason)
    else: # write to csv - reason - no building detected
        prob = 0.0
        reason = "no building detected"
        print(reason)
        
    probility.append(prob)
    reasons.append(reason)
    save.append(detect)

df_clQass = pd.DataFrame(class_save,columns =['class'])
df_idxes = pd.DataFrame(idxes)
df_names = pd.DataFrame(names)
df_save = pd.DataFrame(save)
df_probility = pd.DataFrame(probility)
df_reasons = pd.DataFrame(reasons)
df_class['names'] = df_names
#df_class['img_index']
df_class['idxes'] = df_idxes
df_class['detected_building'] = df_save
df_class['probility'] = df_probility
df_class['reason_unsaved'] = df_reasons
df_class.to_csv('df_class.csv')
# Out:
# Save:  \img_9999.png
# Save:  \img_9997.png
# no building detected
# Save:  \img_9993.png
# no building detected
# no building detected
# Save:  \img_998.png
# no building detected
# prob less than threshold
# no building detected
# no building detected
# no building detected
# Save:  \img_997.png
# prob less than threshold
# Save:  \img_9967.png
# Save:  \img_9961.png
# Save:  \img_996.png
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_9954.png
# Save:  \img_9951.png
# Save:  \img_995.png
# Save:  \img_994.png
# Save:  \img_9930.png
# no building detected
# Save:  \img_9926.png
# Save:  \img_9922.png
# Save:  \img_9921.png
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_9915.png
# no building detected
# prob less than threshold
# Save:  \img_991.png
# no building detected
# Save:  \img_990.png
# no building detected
# no building detected
# Save:  \img_9898.png
# no building detected
# Save:  \img_9895.png
# prob less than threshold
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_9885.png
# Save:  \img_9884.png
# Save:  \img_9883.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_9875.png
# Save:  \img_9874.png
# Save:  \img_9873.png
# no building detected
# Save:  \img_9870.png
# no building detected
# no building detected
# Save:  \img_9867.png
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_9859.png
# Save:  \img_9858.png
# no building detected
# Save:  \img_9854.png
# Save:  \img_9853.png
# Save:  \img_9852.png
# Save:  \img_9851.png
# Save:  \img_985.png
# Save:  \img_9849.png
# Save:  \img_9848.png
# Save:  \img_9847.png
# Save:  \img_9846.png
# Save:  \img_9844.png
# Save:  \img_9842.png
# Save:  \img_9840.png
# prob less than threshold
# no building detected
# Save:  \img_9836.png
# Save:  \img_9835.png
# Save:  \img_983.png
# Save:  \img_9827.png
# Save:  \img_9826.png
# no building detected
# no building detected
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_9813.png
# Save:  \img_981.png
# Save:  \img_9806.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_980.png
# no building detected
# no building detected
# no building detected
# Save:  \img_9794.png
# no building detected
# Save:  \img_9792.png
# no building detected
# Save:  \img_9790.png
# no building detected
# Save:  \img_9789.png
# prob less than threshold
# no building detected
# Save:  \img_978.png
# Save:  \img_9778.png
# prob less than threshold
# Save:  \img_9772.png
# no building detected
# prob less than threshold
# prob less than threshold
# no building detected
# Save:  \img_9765.png
# Save:  \img_9764.png
# no building detected
# Save:  \img_9762.png
# no building detected
# Save:  \img_9760.png
# Save:  \img_9757.png
# Save:  \img_9756.png
# Save:  \img_9754.png
# Save:  \img_9753.png
# no building detected
# prob less than threshold
# Save:  \img_975.png
# Save:  \img_9749.png
# prob less than threshold
# Save:  \img_9746.png
# prob less than threshold
# Save:  \img_9738.png
# Save:  \img_9735.png
# no building detected
# Save:  \img_973.png
# no building detected
# no building detected
# Save:  \img_972.png
# Save:  \img_9719.png
# no building detected
# Save:  \img_9716.png
# no building detected
# Save:  \img_9714.png
# Save:  \img_9713.png
# no building detected
# prob less than threshold
# Save:  \img_971.png
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# prob less than threshold
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_97.png
# no building detected
# Save:  \img_9697.png
# Save:  \img_9696.png
# Save:  \img_9694.png
# no building detected
# no building detected
# no building detected
# Save:  \img_9688.png
# Save:  \img_9687.png
# no building detected
# no building detected
# Save:  \img_9682.png
# Save:  \img_9681.png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_9665.png
# Save:  \img_9664.png
# prob less than threshold
# Save:  \img_966.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_9635.png
# Save:  \img_9634.png
# no building detected
# Save:  \img_9631.png
# no building detected
# no building detected
# Save:  \img_9628.png
# Save:  \img_9626.png
# Save:  \img_9625.png
# no building detected
# Save:  \img_9622.png
# no building detected
# no building detected
# Save:  \img_9617.png
# Save:  \img_9616.png
# Save:  \img_9613.png
# no building detected
# Save:  \img_9610.png
# Save:  \img_961.png
# Save:  \img_9609.png
# Save:  \img_9608.png
# no building detected
# Save:  \img_9606.png
# Save:  \img_9605.png
# no building detected
# Save:  \img_9603.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_96.png
# Save:  \img_9599.png
# Save:  \img_9598.png
# no building detected
# Save:  \img_9596.png
# Save:  \img_9594.png
# no building detected
# prob less than threshold
# Save:  \img_9589.png
# no building detected
# Save:  \img_9577.png
# prob less than threshold
# Save:  \img_9572.png
# no building detected
# Save:  \img_9568.png
# prob less than threshold
# Save:  \img_9561.png
# Save:  \img_9560.png
# Save:  \img_9551.png
# Save:  \img_955.png
# no building detected
# Save:  \img_954.png
# Save:  \img_9537.png
# Save:  \img_9536.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_9529.png
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_9520.png
# Save:  \img_9519.png
# prob less than threshold
# Save:  \img_951.png
# no building detected
# no building detected
# Save:  \img_9502.png
# Save:  \img_9500.png
# no building detected
# no building detected
# Save:  \img_9498.png
# Save:  \img_9496.png
# prob less than threshold
# Save:  \img_9492.png
# Save:  \img_9490.png
# Save:  \img_949.png
# no building detected
# Save:  \img_9483.png
# no building detected
# Save:  \img_948.png
# Save:  \img_947.png
# no building detected
# Save:  \img_9463.png
# no building detected
# no building detected
# Save:  \img_946.png
# Save:  \img_9459.png
# Save:  \img_9457.png
# Save:  \img_9456.png
# Save:  \img_9455.png
# Save:  \img_9454.png
# prob less than threshold
# no building detected
# Save:  \img_945.png
# Save:  \img_9440.png
# Save:  \img_944.png
# Save:  \img_9436.png
# Save:  \img_9433.png
# Save:  \img_9432.png
# Save:  \img_9431.png
# Save:  \img_9430.png
# Save:  \img_9429.png
# no building detected
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_9417.png
# Save:  \img_941.png
# Save:  \img_940.png
# Save:  \img_94.png
# no building detected
# Save:  \img_939.png
# no building detected
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_9371.png
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_9343.png
# Save:  \img_9342.png
# no building detected
# Save:  \img_934.png
# Save:  \img_9339.png
# no building detected
# Save:  \img_9337.png
# prob less than threshold
# no building detected
# Save:  \img_9331.png
# prob less than threshold
# Save:  \img_9328.png
# no building detected
# prob less than threshold
# Save:  \img_932.png
# Save:  \img_9310.png
# Save:  \img_931.png
# Save:  \img_9308.png
# prob less than threshold
# Save:  \img_9306.png
# Save:  \img_9304.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_9292.png
# no building detected
# Save:  \img_929.png
# no building detected
# Save:  \img_9277.png
# no building detected
# Save:  \img_9270.png
# Save:  \img_9266.png
# Save:  \img_9263.png
# Save:  \img_9261.png
# no building detected
# no building detected
# Save:  \img_9257.png
# no building detected
# no building detected
# Save:  \img_9253.png
# no building detected
# Save:  \img_9250.png
# Save:  \img_9249.png
# prob less than threshold
# prob less than threshold
# no building detected
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_9225.png
# no building detected
# no building detected
# Save:  \img_9222.png
# no building detected
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_9210.png
# no building detected
# prob less than threshold
# Save:  \img_9206.png
# no building detected
# Save:  \img_9203.png
# prob less than threshold
# Save:  \img_9200.png
# prob less than threshold
# Save:  \img_9199.png
# prob less than threshold
# Save:  \img_9195.png
# Save:  \img_9194.png
# Save:  \img_9189.png
# no building detected
# Save:  \img_9186.png
# prob less than threshold
# Save:  \img_9184.png
# Save:  \img_9181.png
# prob less than threshold
# Save:  \img_9177.png
# no building detected
# no building detected
# Save:  \img_9172.png
# Save:  \img_9170.png
# Save:  \img_917.png
# no building detected
# Save:  \img_9168.png
# no building detected
# no building detected
# Save:  \img_9165.png
# Save:  \img_9163.png
# Save:  \img_9162.png
# no building detected
# Save:  \img_916.png
# no building detected
# Save:  \img_9156.png
# no building detected
# Save:  \img_9154.png
# Save:  \img_9153.png
# no building detected
# Save:  \img_9148.png
# no building detected
# prob less than threshold
# Save:  \img_9144.png
# no building detected
# no building detected
# Save:  \img_9136.png
# Save:  \img_9135.png
# Save:  \img_9129.png
# prob less than threshold
# Save:  \img_9126.png
# Save:  \img_9119.png
# no building detected
# Save:  \img_9116.png
# no building detected
# Save:  \img_9110.png
# no building detected
# no building detected
# Save:  \img_9086.png
# prob less than threshold
# Save:  \img_9084.png
# Save:  \img_9083.png
# prob less than threshold
png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_82.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_8195.png
# no building detected
# no building detected
# Save:  \img_819.png
# Save:  \img_8187.png
# no building detected
# Save:  \img_8182.png
# prob less than threshold
# Save:  \img_8180.png
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_8167.png
# prob less than threshold
# no building detected
# Save:  \img_8154.png
# Save:  \img_8153.png
# no building detected
# Save:  \img_8150.png
# prob less than threshold
# Save:  \img_8144.png
# Save:  \img_8142.png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_8125.png
# no building detected
# Save:  \img_8122.png
# Save:  \img_8121.png
# Save:  \img_8120.png
# Save:  \img_812.png
# prob less than threshold
# no building detected
# Save:  \img_8117.png
# Save:  \img_8115.png
# Save:  \img_8114.png
# no building detected
# Save:  \img_8112.png
# prob less than threshold
# Save:  \img_811.png
# Save:  \img_8109.png
# Save:  \img_8105.png
# Save:  \img_8102.png
# Save:  \img_8101.png
# no building detected
# Save:  \img_8096.png
# Save:  \img_809.png
# no building detected
# Save:  \img_8084.png
# Save:  \img_808.png
# Save:  \img_8076.png
# no building detected
# prob less than threshold
# no building detected
# no building detected
# no building detected
# Save:  \img_8035.png
# no building detected
# Save:  \img_8028.png
# no building detected
# Save:  \img_8025.png
# prob less than threshold
# Save:  \img_8020.png
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_8016.png
# prob less than threshold
# Save:  \img_8014.png
# Save:  \img_8012.png
# no building detected
# Save:  \img_8010.png
# prob less than threshold
# prob less than threshold
# Save:  \img_8006.png
# Save:  \img_8005.png
# prob less than threshold
# no building detected
# Save:  \img_8001.png
# prob less than threshold
# Save:  \img_7999.png
# Save:  \img_7998.png
# Save:  \img_7997.png
# Save:  \img_7996.png
# no building detected
# no building detected
# prob less than threshold
# no building detected
# prob less than threshold
# no building detected
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_7979.png
# no building detected
# Save:  \img_7967.png
# no building detected
# Save:  \img_7965.png
# no building detected
# Save:  \img_7963.png
# no building detected
# Save:  \img_7961.png
# prob less than threshold
# no building detected
# Save:  \img_7958.png
# Save:  \img_7957.png
# Save:  \img_7948.png
# Save:  \img_7946.png
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_794.png
# no building detected
# Save:  \img_7938.png
# no building detected
# prob less than threshold
# Save:  \img_7934.png
# no building detected
# prob less than threshold
# Save:  \img_793.png
# Save:  \img_7929.png
# Save:  \img_7928.png
# Save:  \img_7923.png
# Save:  \img_7921.png
# Save:  \img_7920.png
# Save:  \img_792.png
# Save:  \img_7918.png
# Save:  \img_7916.png
# Save:  \img_7915.png
# no building detected
# Save:  \img_7913.png
# no building detected
# Save:  \img_7908.png
# no building detected
# Save:  \img_7905.png
# Save:  \img_7904.png
# Save:  \img_7902.png
# Save:  \img_7900.png
# no building detected
# Save:  \img_7899.png
# Save:  \img_7898.png
# Save:  \img_7891.png
# Save:  \img_789.png
# Save:  \img_7888.png
# no building detected
# Save:  \img_7885.png
# prob less than threshold
# no building detected
# Save:  \img_788.png
# no building detected
# no building detected
# no building detected
# Save:  \img_787.png
# no building detected
# Save:  \img_7868.png
# Save:  \img_7867.png
# no building detected
# Save:  \img_7856.png
# Save:  \img_7851.png
# prob less than threshold
# Save:  \img_7849.png
# Save:  \img_7848.png
# prob less than threshold
# Save:  \img_7846.png
# no building detected
# no building detected
# prob less than threshold
# prob less than threshold
# prob less than threshold
# no building detected
# Save:  \img_7831.png
# Save:  \img_7830.png
# Save:  \img_783.png
# no building detected
# Save:  \img_7828.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img
png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_6114.png
# Save:  \img_6112.png
# Save:  \img_6111.png
# Save:  \img_611.png
# no building detected
# Save:  \img_6107.png
# no building detected
# Save:  \img_6105.png
# Save:  \img_6104.png
# no building detected
# Save:  \img_6100.png
# Save:  \img_610.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_6096.png
# Save:  \img_6095.png
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_609.png
# no building detected
# Save:  \img_6088.png
# no building detected
# prob less than threshold
# prob less than threshold
# prob less than threshold
# prob less than threshold
# Save:  \img_6082.png
# Save:  \img_6081.png
# Save:  \img_6080.png
# Save:  \img_608.png
# Save:  \img_6079.png
# Save:  \img_6078.png
# Save:  \img_6077.png
# Save:  \img_6073.png
# no building detected
# prob less than threshold
# Save:  \img_607.png
# prob less than threshold
# Save:  \img_6068.png
# Save:  \img_6067.png
# Save:  \img_6066.png
# Save:  \img_6065.png
# no building detected
# Save:  \img_606.png
# no building detected
# Save:  \img_6054.png
# no building detected
# no building detected
# Save:  \img_6048.png
# prob less than threshold
# no building detected
# Save:  \img_6044.png
# no building detected
# no building detected
# no building detected
# Save:  \img_6037.png
# no building detected
# Save:  \img_6034.png
# Save:  \img_6032.png
# Save:  \img_6031.png
# no building detected
# Save:  \img_603.png
# Save:  \img_6029.png
# Save:  \img_6028.png
# prob less than threshold
# Save:  \img_6025.png
# no building detected
# Save:  \img_6023.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_6018.png
# Save:  \img_6016.png
# no building detected
# no building detected
# Save:  \img_6007.png
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_5997.png
# no building detected
# Save:  \img_5995.png
# no building detected
# Save:  \img_5993.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_5972.png
# Save:  \img_5971.png
# no building detected
# Save:  \img_5966.png
# no building detected
# no building detected
# Save:  \img_5963.png
# Save:  \img_5961.png
# no building detected
# Save:  \img_596.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_5955.png
# Save:  \img_5954.png
# no building detected
# Save:  \img_5951.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_5948.png
# no building detected
# Save:  \img_5946.png
# no building detected
# no building detected
# Save:  \img_5943.png
# no building detected
# Save:  \img_5941.png
# prob less than threshold
# Save:  \img_594.png
# Save:  \img_5938.png
# prob less than threshold
# Save:  \img_5935.png
# Save:  \img_5934.png
# Save:  \img_5933.png
# Save:  \img_5932.png
# prob less than threshold
# no building detected
# Save:  \img_5929.png
# Save:  \img_5928.png
# Save:  \img_5927.png
# no building detected
# no building detected
# Save:  \img_5924.png
# Save:  \img_5922.png
# no building detected
# prob less than threshold
# Save:  \img_5918.png
# Save:  \img_5917.png
# Save:  \img_5916.png
# Save:  \img_5915.png
# Save:  \img_5914.png
# prob less than threshold
# Save:  \img_5912.png
# Save:  \img_5911.png
# no building detected
# Save:  \img_5908.png
# Save:  \img_5907.png
# no building detected
# Save:  \img_5905.png
# prob less than threshold
# Save:  \img_5900.png
# prob less than threshold
# prob less than threshold
# prob less than threshold
# Save:  \img_5896.png
# prob less than threshold
# no building detected
# Save:  \img_5892.png
# Save:  \img_5890.png
# Save:  \img_5888.png
# no building detected
# no building detected
# Save:  \img_5873.png
# Save:  \img_5872.png
# no building detected
# Save:  \img_587.png
# Save:  \img_5868.png
# no building detected
# prob less than threshold
# Save:  \img_5865.png
# no building detected
# Save:  \img_5862.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_10888.png
# Save:  \img_10885.png
# Save:  \img_10883.png
# Save:  \img_10882.png
# Save:  \img_10881.png
# prob less than threshold
# Save:  \img_10879.png
# Save:  \img_10878.png
# Save:  \img_10877.png
# no building detected
# prob less than threshold
# Save:  \img_10869.png
# no building detected
# no building detected
# Save:  \img_1085.png
# Save:  \img_10840.png
# prob less than threshold
# Save:  \img_10836.png
# Save:  \img_10835.png
# prob less than threshold
# Save:  \img_10832.png
# Save:  \img_10831.png
# Save:  \img_10830.png
# prob less than threshold
# Save:  \img_10829.png
# no building detected
# prob less than threshold
# Save:  \img_10825.png
# no building detected
# Save:  \img_10822.png
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10800.png
# Save:  \img_108.png
# no building detected
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_10789.png
# Save:  \img_10788.png
# no building detected
# Save:  \img_10782.png
# no building detected
# Save:  \img_10779.png
# prob less than threshold
# no building detected
# no building detected
# no building detected
# Save:  \img_10774.png
# Save:  \img_10773.png
# Save:  \img_10769.png
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_10764.png
# no building detected
# Save:  \img_10761.png
# prob less than threshold
# Save:  \img_10759.png
# prob less than threshold
# prob less than threshold
# Save:  \img_10749.png
# Save:  \img_10748.png
# Save:  \img_10747.png
# Save:  \img_10746.png
# Save:  \img_10745.png
# Save:  \img_10725.png
# Save:  \img_10722.png
# Save:  \img_10719.png
# no building detected
# prob less than threshold
# Save:  \img_10714.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_107.png
# no building detected
# Save:  \img_10698.png
# no building detected
# no building detected
# Save:  \img_10685.png
# Save:  \img_10683.png
# no building detected
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_10678.png
# no building detected
# Save:  \img_10675.png
# Save:  \img_10672.png
# Save:  \img_10670.png
# no building detected
# Save:  \img_10666.png
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_10656.png
# Save:  \img_10653.png
# no building detected
# Save:  \img_10640.png
# no building detected
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_10630.png
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_10627.png
# Save:  \img_10626.png
# no building detected
# prob less than threshold
# Save:  \img_10620.png
# Save:  \img_10619.png
# prob less than threshold
# Save:  \img_10617.png
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_10607.png
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_10603.png
# Save:  \img_10602.png
# Save:  \img_106.png
# prob less than threshold
# Save:  \img_10598.png
# Save:  \img_10597.png
# Save:  \img_10596.png
# prob less than threshold
# Save:  \img_10594.png
# no building detected
# prob less than threshold
# prob less than threshold
# Save:  \img_10589.png
# Save:  \img_10588.png
# Save:  \img_10587.png
# Save:  \img_10586.png
# Save:  \img_10584.png
# prob less than threshold
# Save:  \img_10581.png
# Save:  \img_10580.png
# Save:  \img_10575.png
# prob less than threshold
# no building detected
# Save:  \img_10571.png
# no building detected
# Save:  \img_1057.png
# Save:  \img_10569.png
# Save:  \img_10568.png
# no building detected
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10558.png
# Save:  \img_10557.png
# prob less than threshold
# Save:  \img_10554.png
# Save:  \img_10553.png
# prob less than threshold
# Save:  \img_1055.png
# Save:  \img_10546.png
# no building detected
# no building detected
# Save:  \img_10543.png
# prob less than threshold
# Save:  \img_1054.png
# Save:  \img_10538.png
# no building detected
# Save:  \img_10536.png
# no building detected
# no building detected
# Save:  \img_10532.png
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_10515.png
# no building detected
# Save:  \img_10511.png
# Save:  \img_10510.png
# Save:  \img_10509.png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10502.png
# no building detected
# no building detected
# Save:  \img_105.png
# no building detected
# Save:  \img_10498.png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10478.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10470.png
# Save:  \img_1047.png
# Save:  \img_10461.png
# Save:  \img_10460.png
# Save:  \img_1046.png
# prob less than threshold
# no building detected
# Save:  \img_1045.png
# no building detected
# prob less than threshold
# Save:  \img_10427.png
# Save:  \img_1042.png
# Save:  \img_10416.png
# Save:  \img_1041.png
# Save:  \img_1040.png
# no building detected
# no building detected
# prob less than threshold
# no building detected
# Save:  \img_1038.png
# Save:  \img_1036.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_10352.png
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_1034.png
# Save:  \img_10338.png
# no building detected
# prob less than threshold
# Save:  \img_10331.png
# prob less than threshold
# no building detected
# no building detected
# no building detected
# Save:  \img_10321.png
# no building detected
# no building detected
# no building detected
# Save:  \img_1031.png
# prob less than threshold
# no building detected
# no building detected
# no building detected
# Save:  \img_103.png
# no building detected
# no building detected
# Save:  \img_10294.png
# no building detected
# Save:  \img_10290.png
# no building detected
# prob less than threshold
# prob less than threshold
# no building detected
# no building detected
# Save:  \img_10269.png
# no building detected
# no building detected
# Save:  \img_1026.png
# Save:  \img_10259.png
# no building detected
# no building detected
# Save:  \img_10239.png
# no building detected
# Save:  \img_10234.png
# prob less than threshold
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10217.png
# no building detected
# Save:  \img_10215.png
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10205.png
# Save:  \img_1020.png
# prob less than threshold
# prob less than threshold
# Save:  \img_1019.png
# no building detected
# no building detected
# Save:  \img_10181.png
# no building detected
# no building detected
# Save:  \img_10166.png
# Save:  \img_10163.png
# no building detected
# no building detected
# no building detected
# prob less than threshold
# Save:  \img_10156.png
# Save:  \img_10155.png
# Save:  \img_10154.png
# Save:  \img_10150.png
# Save:  \img_10149.png
# Save:  \img_10148.png
# Save:  \img_10145.png
# prob less than threshold
# Save:  \img_10143.png
# no building detected
# Save:  \img_10139.png
# Save:  \img_10138.png
# Save:  \img_10137.png
# prob less than threshold
# prob less than threshold
# Save:  \img_10130.png
# no building detected
# Save:  \img_10128.png
# no building detected
# no building detected
# no building detected
# Save:  \img_10110.png
# Save:  \img_10109.png
# no building detected
# no building detected
# prob less than threshold
# prob less than threshold
# prob less than threshold
# no building detected
# prob less than threshold
# Save:  \img_10099.png
# Save:  \img_10098.png
# Save:  \img_10097.png
# Save:  \img_10096.png
# Save:  \img_10095.png
# no building detected
# no building detected
# Save:  \img_10087.png
# no building detected
# prob less than threshold
# Save:  \img_10084.png
# no building detected
# Save:  \img_1008.png
# Save:  \img_1007.png
# Save:  \img_10069.png
# no building detected
# Save:  \img_10062.png
# no building detected
# Save:  \img_10057.png
# no building detected
# Save:  \img_10055.png
# Save:  \img_10052.png
# prob less than threshold
# prob less than threshold
# Save:  \img_1005.png
# no building detected
# Save:  \img_10048.png
# prob less than threshold
# Save:  \img_10045.png
# Save:  \img_10042.png
# prob less than threshold
# Save:  \img_1004.png
# Save:  \img_10037.png
# prob less than threshold
# prob less than threshold
# Save:  \img_10034.png
# no building detected
# Save:  \img_10029.png
# Save:  \img_10028.png
# no building detected
# no building detected
# no building detected
# no building detected
# no building detected
# Save:  \img_10006.png
# no building detected
# no building detected
# Save:  \img_10002.png
# Save:  \img_10001.png
# Save:  \img_10000.png
# Save:  \img_1000.png
# Save:  \img_100.png
# no building detected
# Save:  \img_1.png
# no building detected

# %%
# Load the data
df = pd.read_csv("data/stats_facade_detection.csv")
df.head()
df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']] = df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']].replace(to_replace = 0.0, value = False)
df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']] = df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']].replace(to_replace = 1.0, value = True)
# Out:
#    img_index          Building               Road     Heading   Errors  \
# 0          0  47.42829 8.63718    47.4282 8.63708  408.012788        0
# 1          1  47.43052 8.63819   47.43047 8.63831  292.619865        0
# 2          2  47.43063 8.63873   47.43071 8.63863  488.659808        0
# 3          3   47.43115 8.6394   47.43107 8.63947  318.814075        0
# 4          4  47.43126 8.63966   47.43117 8.63974  318.366461        0
#
#    Download reason_x                     class       names  Building_idxes  \
# 0      True     None  residential_neighborhood  \img_0.png           283.0
# 1      True     None                   cottage  \img_1.png           107.0
# 2      True     None                     house  \img_2.png           183.0
# 3      True     None                   cottage  \img_3.png           107.0
# 4      True     None                    chalet  \img_4.png            87.0
#
#    detected_building  probility        reason_unsaved       name  \
# 0                0.0   0.000000  no building detected        NaN
# 1                1.0   0.110487                  None  img_1.jpg
# 2                1.0   0.180126                  None  img_2.jpg
# 3                1.0   0.176232                  None  img_3.jpg
# 4                1.0   0.119446                  None  img_4.jpg
#
#    save_after_greenSSD         reason_y  save_after_original_ssd
# 0                  NaN              NaN                      NaN
# 1                  1.0             None                      1.0
# 2                  1.0             None                      1.0
# 3                  1.0             None                      1.0
# 4                  0.0  too many greens                      NaN

# %%
df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']] = df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']].replace(to_replace = 0.0, value = False)
df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']] = df[['detected_building', 'save_after_greenSSD', 'save_after_original_ssd']].replace(to_replace = 1.0, value = True)

# %%
df.to_csv('detect_facade.csv')

# %%
df.save_after_greenSSD.value_counts()
# Out:
# True     2853
# False     202
# Name: save_after_greenSSD, dtype: int64

# %%
df.save_after_original_ssd.value_counts()
# Out:
# True     2481
# False     225
# Name: save_after_original_ssd, dtype: int64

# %%
temp = df[df['detected_building'] == True]
mean_1 = temp['probility'].mean()
mean_1
# Out:
# 0.20587808915810132

# %%
temp = temp[temp['save_after_greenSSD']==True]
mean_2 = temp['probility'].mean()
mean_2
# Out:
# 0.20542501091062032

# %%
temp = temp[temp['save_after_original_ssd']==True]
mean_3 = temp['probility'].mean()
mean_3
# Out:
# 0.20609914460056397
