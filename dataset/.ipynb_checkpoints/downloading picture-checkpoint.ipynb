# %%
"""
This includes the main function img_from_db which is used by the pipeline to create images.
It also includes helper functions for images stitching which can be used by adding
sample = True to the list of args in run.py for the "args.sample" command, or by changing the default
to sample = True in the img_from_db function
imgs_copied.txt: used to store the amoung of images already pulled from the API
imgs_copied_stitched.txt: same function, but if you are pulling stitched images
"""
import shapefile
import google_streetview.api
import googlemaps
#from gmaps import Roads
import math
import os
import shutil

# from sample.py
import tempfile
from PIL import Image
import random as rand

# for image_stitching
from imutils import paths
import numpy as np
import argparse
import imutils
import os.path
from cv2 import cv2

# for make_dataset
from make_dataset import img_from_db
from make_dataset import img_stitch

this_path = ""

# %%
# c=(47.37593, 8.54457)
# params = [{
#                 'size': '300x300',  # max 640x640 pixels
#                 'location': str(c[0]) + ',' + str(c[1]),
#                 'heading': 90,
#                 'pitch': '25',
#                 'fov': '120',
#                 'key': 'AIzaSyDfqR9EWkkk-4qMG21VJbU-kA5n6yhBu0E'
#             }]  
# results = google_streetview.api.results(params)
# results.download_links("./")

# %%
img_from_db(30, final_path="", path="./", stitch = False)
# Out:
# 0
# from database: (47.42829, 8.63718)
# from snapped to road: [47.4282, 8.63708]
# heading: 408.012787504577
# [{'size': '300x300', 'location': '47.4282,8.63708', 'heading': '378.012787504577', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4282,8.63708', 'heading': '408.012787504577', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4282,8.63708', 'heading': '438.012787504577', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 1
# from database: (47.43052, 8.63819)
# from snapped to road: [47.43047, 8.63831]
# heading: 292.6198649485824
# [{'size': '300x300', 'location': '47.43047,8.63831', 'heading': '262.6198649485824', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43047,8.63831', 'heading': '292.6198649485824', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43047,8.63831', 'heading': '322.6198649485824', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 2
# from database: (47.43063, 8.63873)
# from snapped to road: [47.43071, 8.63863]
# heading: 488.65980825260067
# [{'size': '300x300', 'location': '47.43071,8.63863', 'heading': '458.65980825260067', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43071,8.63863', 'heading': '488.65980825260067', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43071,8.63863', 'heading': '518.6598082526007', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 3
# from database: (47.43115, 8.6394)
# from snapped to road: [47.43107, 8.63947]
# heading: 318.8140748360917
# [{'size': '300x300', 'location': '47.43107,8.63947', 'heading': '288.8140748360917', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43107,8.63947', 'heading': '318.8140748360917', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43107,8.63947', 'heading': '348.8140748360917', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 4
# from database: (47.43126, 8.63966)
# from snapped to road: [47.43117, 8.63974]
# heading: 318.36646066328944
# [{'size': '300x300', 'location': '47.43117,8.63974', 'heading': '288.36646066328944', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43117,8.63974', 'heading': '318.36646066328944', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43117,8.63974', 'heading': '348.36646066328944', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 5
# from database: (47.4315, 8.64003)
# from snapped to road: [47.43134, 8.64017]
# heading: 318.8140748344705
# [{'size': '300x300', 'location': '47.43134,8.64017', 'heading': '288.8140748344705', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43134,8.64017', 'heading': '318.8140748344705', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43134,8.64017', 'heading': '348.8140748344705', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
#
 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.43037,8.64165', 'heading': '459.44395478104394', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 26
# from database: (47.42991, 8.64215)
# from snapped to road: [47.42988, 8.64205]
# heading: 433.3007557649793
# [{'size': '300x300', 'location': '47.42988,8.64205', 'heading': '403.3007557649793', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.42988,8.64205', 'heading': '433.3007557649793', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.42988,8.64205', 'heading': '463.3007557649793', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 27
# from database: (47.42914, 8.64375)
# from snapped to road: [47.4292, 8.64394]
# heading: 252.47443162494403
# [{'size': '300x300', 'location': '47.4292,8.64394', 'heading': '222.47443162494403', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4292,8.64394', 'heading': '252.47443162494403', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4292,8.64394', 'heading': '282.47443162494403', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 28
# from database: (47.4296, 8.64192)
# from snapped to road: [47.4296, 8.64183]
# heading: 450.0
# [{'size': '300x300', 'location': '47.4296,8.64183', 'heading': '420.0', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4296,8.64183', 'heading': '450.0', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.4296,8.64183', 'heading': '480.0', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)
# 29
# from database: (47.42899, 8.64096)
# from snapped to road: [47.42915, 8.64076]
# heading: 488.6598082543383
# [{'size': '300x300', 'location': '47.42915,8.64076', 'heading': '458.6598082543383', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.42915,8.64076', 'heading': '488.6598082543383', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [{'size': '300x300', 'location': '47.42915,8.64076', 'heading': '518.6598082543383', 'pitch': '25', 'fov': '120', 'source': 'outdoor', 'key': 'AIzaSyAwTObZ9-lfhdw9blad_ce4SUX5PWsufTI'}]
# [INFO] image stitching failed (1)

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as patches

imgPaths = sorted(list(paths.list_images("stitchUnlabel")))
imgs = []

for imgPath in imgPaths:
    img = cv2.imread(imgPath)
    imgs.append(img)

for img in imgs:
    # resize image
    width = img.shape[1]
    #width = int(img.shape[1] * 80 / 100) 
    height = 300
    dsize = (width, height)
    output = cv2.resize(img, dsize)
    center = [output.shape[0] / 2, output.shape[1] / 2]
    x = center[1] - 150
    y = center[0] - 150
    crop_img = output[int(y):int(y+300), int(x):int(x+300)]
    
    # get number of images already in the ./cropped_img directory
    imgCount = len([name for name in os.listdir('cropped_img') if os.path.isfile(os.path.join('cropped_img', name))]) - 1

    # write the output stitched image to disk (adding 1 to imgCount bc first image is gsv1 not gsv0)
    cv2.imwrite('cropped_img' + '/gsv'+ str(imgCount+1) + '.jpg', crop_img)

# %%
#it is aiming to combine the same picture and ready to test with pix2pix model
imgPaths = sorted(list(paths.list_images(this_path + "cropped_img")))
imgs = []
i = 0
for imgPath in imgPaths:
    img = cv2.imread(imgPath)
    imgs.append(img)
    imgs.append(img)
    image = cv2.hconcat([imgs[0],imgs[1]])
#     cv2.imshow('image',image)
#     cv2.waitKey()
#     cv2.destroyAllWindows()
    cv2.imwrite(this_path + 'copy_combine' + '/gsv'+ str(i) + '.jpg', image)
    i = i+1
    imgs = []

# %%
# Out:
# 2624
